# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Preprocessing
# EDA is done in a separate notebook.

# %%
df = pd.read_csv("ingredients.csv", sep = ";", header=1)
df.dtypes
# Out:
# NDB_No              str
# Descrip             str
# Energy_kcal         str
# Protein_g           str
# Saturated_fats_g    str
# Fat_g               str
# Carb_g              str
# Fiber_g             str
# Sugar_g             str
# Calcium_mg          str
# Iron_mg             str
# Magnesium_mg        str
# Phosphorus_mg       str
# Potassium_mg        str
# Sodium_mg           str
# Zinc_mg             str
# Copper_mcg          str
# Manganese_mg        str
# Selenium_mcg        str
# VitC_mg             str
# Thiamin_mg          str
# Riboflavin_mg       str
# Niacin_mg           str
# VitB6_mg            str
# Folate_mcg          str
# VitB12_mcg          str
# VitA_mcg            str
# VitE_mg             str
# VitD2_mcg           str
# dtype: object

# %%
df
# Out:
#                                                  NDB_No  \
# 0                                                  6312
# 1                                                 28000
# 2                                                 10877
# 3                                                  8615
# 4                                                 42289
# ...                                                 ...
# 20500                                              A022
# 20501                                              3133
# 20502                                             36031
# 20503  >>>>>>> 711c908eaf681e7424f649ac1b29433943697b28
# 20504                                               NaN
#
#                                                  Descrip Energy_kcal  \
# 0       campbell's red  white crm of asparagus soup cond          89
# 1              kellogg's eggo mini muffin tops choc chip         300
# 2      pork cured ham  h2o product rump bone-in ln ht...         131
# ...

# %%
df["Descrip"].str.lower().str.strip().duplicated().sum()
# Out:
# np.int64(11189)

# %%
df0 = df.drop_duplicates()
print(len(df0))
print(len(df))
# Out:
# 9390
# 20505

# %%
excl = ["Descrip"]
cols_conv = df.columns.difference(excl)
df0[cols_conv] = df0[cols_conv].apply(
    lambda col: pd.to_numeric(col, errors="coerce")
)

# %%
# Out:
# NDB_No              True
# Descrip             True
# Energy_kcal         True
# Protein_g           True
# Saturated_fats_g    True
# Fat_g               True
# Carb_g              True
# Fiber_g             True
# Sugar_g             True
# Calcium_mg          True
# Iron_mg             True
# Magnesium_mg        True
# Phosphorus_mg       True
# Potassium_mg        True
# Sodium_mg           True
# Zinc_mg             True
# Copper_mcg          True
# Manganese_mg        True
# Selenium_mcg        True
# VitC_mg             True
# Thiamin_mg          True
# Riboflavin_mg       True
# Niacin_mg           True
# VitB6_mg            True
# Folate_mcg          True
# VitB12_mcg          True
# VitA_mcg            True
# VitE_mg             True
# VitD2_mcg           True
# dtype: bool
